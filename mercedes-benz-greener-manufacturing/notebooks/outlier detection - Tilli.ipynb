# %%
__author__ = 'Tilii: https://kaggle.com/tilii7'


import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import os
import time
from datetime import timedelta
from matplotlib.ticker import MultipleLocator

import warnings
with warnings.catch_warnings():
    warnings.filterwarnings('ignore',category=DeprecationWarning)
    import pandas as pd
    import numpy as np
    from datetime import datetime
    from sklearn.ensemble import IsolationForest
    from sklearn.model_selection import cross_val_predict
    from sklearn.ensemble import RandomForestRegressor
    from sklearn.manifold import TSNE
    import pprint

# %%
# constants
DATA_PATH = '/kaggle/dev/mercedes-benz-greener-manufacturing-data/raw_data/'
SUBMISSION_PATH = '/kaggle/dev/mercedes-benz-greener-manufacturing-data/submissions'
ENSEMBLE_PATH = '/kaggle/dev/mercedes-benz-greener-manufacturing-data/ensemble/jsardinha/'
ASSET_PATH = '/kaggle/dev/jovan/mercedes-benz-greener-manufacturing/mercedes-benz-greener-manufacturing/assets/'

threshold_list = [[0.0, '0-0'], [0.5, '0-5'], [1.0, '1-0'], [1.5, '1-5'], [2.0, '2-0'],[2.5, '2-5'], [3.0, '3-0'],
                  [3.5, '3-5'], [4.0, '4-0'],[4.5, '4-5']]

# %%
# from https://stackoverflow.com/questions/22354094/pythonic-way-of-detecting-outliers-in-one-dimensional-observation-data
def is_outlier(points, thresh=3.5):
    '''
    Returns a boolean array with True if points are outliers and False
    otherwise.

    Parameters:
    -----------
        points : An numobservations by numdimensions array of observations
        thresh : The modified z-score to use as a threshold. Observations with
            a modified z-score (based on the median absolute deviation) greater
            than this value will be classified as outliers.

    Returns:
    --------
        mask : A numobservations-length boolean array.

    References:
    ----------
        Boris Iglewicz and David Hoaglin (1993), 'Volume 16: How to Detect and
        Handle Outliers', The ASQC Basic References in Quality Control:
        Statistical Techniques, Edward F. Mykytka, Ph.D., Editor.
    '''
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return (modified_z_score, (modified_z_score > thresh) )

def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        tmin, tsec = divmod((datetime.now() - start_time).total_seconds(), 60)
        print(' Time taken: %i minutes and %s seconds.' % (tmin, round(tsec,2)))

if __name__ == '__main__':
    
    for i , threshold in enumerate(threshold_list):
        print('------ RUNNING for treshold:', threshold[0])
        RFR = RandomForestRegressor(n_estimators=100)
        tsne = TSNE(n_components=2, n_iter_without_progress=50, init='pca', verbose=2, random_state=1001)

    # Load data set and target values
        start_time = timer(None)
        print('\n# Reading and Processing Data')
        train = pd.read_csv(os.path.join(DATA_PATH, 'train.csv'), dtype={'ID': np.int32, 'y': np.float32})
        target = train['y'].values
        train_ids = train['ID'].values
        train = train.drop(['ID', 'y'], axis=1)
        print('\n Initial Train Set Matrix Dimensions: %d x %d' % (train.shape[0], train.shape[1]))
        train_len = len(train)
        test = pd.read_csv(os.path.join(DATA_PATH, 'test.csv'), dtype={'ID': np.int32})
        test_ids = test['ID'].values
        test = test.drop(['ID'], axis=1)
        print('\n Initial Test Set Matrix Dimensions: %d x %d' % (test.shape[0], test.shape[1]))

    # Sort out numerical and categorical features
        all_data = pd.concat((train, test))
        numeric_feats = all_data.dtypes[all_data.dtypes != 'object'].index
        categorical_feats = all_data.dtypes[all_data.dtypes == 'object'].index

        print('\n Converting categorical features:')
        for i, col_name in enumerate(categorical_feats):
            print(' Converting %s' % col_name)
            temp_df = pd.get_dummies(all_data[col_name])
            new_features = temp_df.columns.tolist()
            new_features = [col_name + '_' + w for w in new_features]
            temp_df.columns = new_features
            all_data.drop(col_name, axis=1, inplace=True)
            all_data = pd.concat((all_data, temp_df), axis=1)

    # Remove columns where all data points have the same value
        print('\n Number of columns before cleaning: %d' % len(all_data.columns))
        cols = all_data.columns.tolist()
        for column in cols:
            if len(np.unique(all_data[column])) == 1:
                print(' Column %s removed' % str(column))
                all_data.drop(column, axis=1, inplace=True)

    # Remove identical columns where all data points have the same value
        cols = all_data.columns.tolist()
        remove = []
        for i in range(len(cols)-1):
            v = all_data[cols[i]].values
            for j in range(i+1,len(cols)):
                if np.array_equal(v,all_data[cols[j]].values):
                    remove.append(cols[j])
                    print(' Column %s is identical to %s. Removing %s' % (str(cols[i]), str(cols[j]), str(cols[j])))

        all_data.drop(remove, axis=1, inplace=True)
        print('\n Number of columns after cleaning: %d' % len(all_data.columns))

        features = all_data.columns
        print('\n Final Matrix Dimensions: %d x %d' % (all_data.shape[0], all_data.shape[1]))
        train_data = pd.DataFrame(all_data[ : train_len].values, columns=features)
        test_data = pd.DataFrame(all_data[train_len : ].values, columns=features)
        train_data.reset_index(drop=True, inplace=True)
        test_data.reset_index(drop=True, inplace=True)
        timer(start_time)

        start_time = timer(None)
        print('\n Calculating t-SNE embedding:')
        all_data_tsne = tsne.fit_transform(all_data)
        train_data_tsne = pd.DataFrame(all_data_tsne[ : train_len], columns=['tsne_x','tsne_y'])
        test_data_tsne = pd.DataFrame(all_data_tsne[train_len : ], columns=['tsne_x','tsne_y'])
        train_data_tsne.reset_index(drop=True, inplace=True)
        test_data_tsne.reset_index(drop=True, inplace=True)
        timer(start_time)

    #Running isolation forest to remove outliers
        start_time = timer(None)
        clf = IsolationForest(n_estimators=500, max_samples=1.0, random_state=1001, bootstrap=True, contamination=0.02, verbose=0, n_jobs=-1)
        print('\n Running Isolation Forest:')
        clf.fit(train_data.values, target)
        isof = clf.predict(train_data.values)
        train.insert(0, 'y', target)
        train.insert(0, 'ID', train_ids)
        train['isof'] = isof
        myindex = train['isof'] < 0
        train_IF = train.loc[myindex]
        train_IF.reset_index(drop=True, inplace=True)
        train_IF.drop('isof', axis=1, inplace=True)
        #train_IF.to_csv('train-isof-outliers.csv', index=False)
        test.insert(0, 'ID', test_ids)
        test['isof'] = clf.predict(test_data.values)
        myindex = test['isof'] < 0
        test_IF = test.loc[myindex]
        test_IF.reset_index(drop=True, inplace=True)
        test_IF.drop('isof', axis=1, inplace=True)
        #test_IF.to_csv('test-isof-outliers.csv', index=False)
        print('\n Found %d outlier points' % len(train_IF))
        timer(start_time)

        start_time = timer(None)
        print('\n Running Random Forest Regressor (10-fold):')
        target_pred = cross_val_predict(estimator=RFR, X=train_data.values, y=target, cv=10, n_jobs=-1)
        rfr_pred = pd.DataFrame({'ID': train_ids, 'y': target, 'y_pred': target_pred})
        #rfr_pred.to_csv('prediction-train-oof-10fold-RFR.csv', index=False)
        yvalues = np.vstack((target, target_pred)).transpose()
        OL_score, OL = is_outlier(yvalues, threshold[0])
        train['outlier_score'] = OL_score
        myindex = train['outlier_score'] >= threshold[0]
        train_OL = train.loc[myindex]
        train_OL.reset_index(drop=True, inplace=True)
        train_OL.drop(['isof','outlier_score'], axis=1, inplace=True)
        #train_OL.to_csv('train-outliers.csv', index=False)
        train_OL.to_csv(os.path.join(ASSET_PATH, 'train-outliers_' + threshold[1] + '.csv'), index=False)
        timer(start_time)

        start_time = timer(None)
        train_outliers_tsne = train_data_tsne.loc[myindex]
        test_outliers_tsne = test_data_tsne.values
        outlier_list = []
        for k in range(len(train_outliers_tsne)):
            d = ((test_outliers_tsne-train_outliers_tsne.values[k])**2).sum(axis=1)  # compute distances
            ndx = d.argsort() # sort so that smallest distance is first
            print(' Presumed outlier point for train ID = %d is test ID = %d ; their Euclidean distance from t-SNE embedding is %.8f' % (train_OL.iloc[k]['ID'], test.iloc[ndx[0]]['ID'], d[ndx[0]]))
            outlier_list.append(ndx[0])
            print(' Ten closest test points (ID, distance):')
            pprint.pprint(zip(test.iloc[ndx[:10]]['ID'], d[ndx[:10]]))

        test_OL = test.iloc[outlier_list]
        test_OL.drop(['isof'], axis=1, inplace=True)
        test_OL.sort_values(['ID'], inplace=True)
        test_OL.reset_index(drop=True, inplace=True)
        test_OL.to_csv(os.path.join(ASSET_PATH, 'test-outliers_' + threshold[1] + '.csv'), index=False)

        timer(start_time)
# Out:
# ------ RUNNING for treshold: 0.0
#
# # Reading and Processing Data
#
#  Initial Train Set Matrix Dimensions: 4209 x 376
#
#  Initial Test Set Matrix Dimensions: 4209 x 376
#
#  Converting categorical features:
#  Converting X0
#  Converting X1
#  Converting X2
#  Converting X3
#  Converting X4
#  Converting X5
#  Converting X6
#  Converting X8
#
#  Number of columns before cleaning: 579
#  Column X16 is identical to X2_ap. Removing X2_ap
#  Column X17 is identical to X382. Removing X382
#  Column X23 is identical to X2_f. Removing X2_f
#  Column X26 is identical to X2_b. Removing X2_b
#  Column X28 is identical to X2_n. Removing X2_n
#  Column X30 is identical to X2_ag. Removing X2_ag
#  Column X31 is identical to X35. Removing X35
#  Column X31 is identical to X37. Removing X37
#  Column X32 is identical to X2_a. Removing X2_a
#  Column X33 is identical to X39. Removing X39
#  Column X35 is identical to X37. Removing X37
#  Column X36 is identical to X2_z. Removing X2_z
#  Column X44 is identical to X302. Removing X302
#  Column X48 is identical to X113. Removing X113
#  Column X48 is identical to X134. Removing X134
#  Column X48 is identical to X147. Removing X147
#  Column X48 is identical to X222. Removing X222
#  Column X48 is identical to X2_s. Removing X2_s
#  Column X53 is identical to X102. Removing X102
#  Column X53 is identical to X214. Removing X214
#  Column X53 is identical to X239. Removing X239
#  Column X53 is identical to X2_t. Removing X2_t
#  Column X54 is identical to X76. Removing X76
#  Column X58 is identical to X324. Removing X324
#  Column X59 is identical to X2_au. Removing X2_au
#  Column X60 is identical to X253. Removing X253
#  Column X60 is identical to X385. Removing X385
#  Column X62 is identical to X172. Removing X172
#  Column X62 is identical to X216. Removing X216
#  Column X62 is identical to X2_k. Removing X2_k
#  Column X67 is identical to X213. Removing X213
#  Column X67 is identical to X2_aw. Removing X2_aw
#  Column X71 is identical to X84. Removing X84
#  Column X71 is identical to X244. Removing X244
#  Column X83 is identical to X2_q. Removing X2_q
#  Column X84 is identical to X244. Removing X244
#  Column X86 is identical to X2_h. Removing X2_h
#  Column X92 is identical to X2_p. Removing X2_p
#  Column X97 is identical to X2_d. Removing X2_d
#  Column X102 is identical to X214. Removing X214
#  Column X102 is identical to X239. Removing X239
#  Column X102 is identical to X2_t. Removing X2_t
#  Column X107 is identical to X2_ad. Removing X2_ad
#  Column X112 is identical to X199. Removing X199
#  Column X112 is identical to X2_g. Removing X2_g
#  Column X113 is identical to X134. Removing X134
#  Column X113 is identical to X147. Removing X147
#  Column X113 is identical to X222. Removing X222
#  Column X113 is identical to X2_s. Removing X2_s
#  Column X118 is identical to X119. Removing X119
#  Column X125 is identical to X227. Removing X227
#  Column X125 is identical to X2_ac. Removing X2_ac
#  Column X134 is identical to X147. Removing X147
#  Column X134 is identical to X222. Removing X222
#  Column X134 is identical to X2_s. Removing X2_s
#  Column X138 is identical to X146. Removing X146
#  Column X147 is identical to X222. Removing X222
#  Column X147 is identical to X2_s. Removing X2_s
#  Column X152 is identical to X226. Removing X226
#  Column X152 is identical to X326. Removing X326
#  Column X155 is identical to X360. Removing X360
#  Column X172 is identical to X216. Removing X216
#  Column X172 is identical to X2_k. Removing X2_k
#  Column X184 is identical to X262. Removing X262
#  Column X184 is identical to X2_at. Removing X2_at
#  Column X199 is identical to X2_g. Removing X2_g
#  Column X211 is identical to X2_aq. Removing X2_aq
#  Column X213 is identical to X2_aw. Removing X2_aw
#  Column X214 is identical to X239. Removing X239
#  Column X214 is identical to X2_t. Removing X2_t
#  Column X215 is identical to X2_ai. Removing X2_ai
#  Column X216 is identical to X2_k. Removing X2_k
#  Column X222 is identical to X2_s. Removing X2_s
#  Column X226 is identical to X326. Removing X326
#  Column X227 is identical to X2_ac. Removing X2_ac
#  Column X230 is identical to X254. Removing X254
#  Column X232 is identical to X279. Removing X279
#  Column X239 is identical to X2_t. Removing X2_t
#  Column X240 is identical to X364. Removing X364
#  Column X251 is identical to X2_as. Removing X2_as
#  Column X253 is identical to X385. Removing X385
#  Column X257 is identical to X2_o. Removing X2_o
#  Column X260 is identical to X2_am. Removing X2_am
#  Column X262 is identical to X2_at. Removing X2_at
#  Column X277 is identical to X0_bc. Removing X0_bc
#  Column X290 is identical to X293. Removing X293
#  Column X290 is identical to X330. Removing X330
#  Column X293 is identical to X330. Removing X330
#  Column X295 is identical to X296. Removing X296
#  Column X298 is identical to X299. Removing X299
#
#  Number of columns after cleaning: 517
#
#  Final Matrix Dimensions: 8418 x 517
#  Time taken: 0 minutes and 3.67 seconds.
#
#  Calculating t-SNE embedding:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8418
# [t-SNE] Computed conditional probabilities for sample 2000 / 8418
# [t-SNE] Computed conditional probabilities for sample 3000 / 8418
# [t-SNE] Computed conditional probabilities for sample 4000 / 8418
# [t-SNE] Computed conditional probabilities for sample 5000 / 8418
# [t-SNE] Computed conditional probabilities for sample 6000 / 8418
# [t-SNE] Computed conditional probabilities for sample 7000 / 8418
# [t-SNE] Computed conditional probabilities for sample 8000 / 8418
# [t-SNE] Computed conditional probabilities for sample 8418 / 8418
# [t-SNE] Mean sigma: 1.247069
# [t-SNE] Iteration 25: error = 1.4710975, gradient norm = 0.0039841
# [t-SNE] Iteration 50: error = 1.4560602, gradient norm = 0.0036393
# [t-SNE] Iteration 75: error = 1.3648686, gradient norm = 0.0024294
# [t-SNE] Iteration 100: error = 1.3346347, gradient norm = 0.0021887
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 1.334635
# [t-SNE] Iteration 125: error = 1.2733716, gradient norm = 0.0017893
# [t-SNE] Iteration 150: error = 1.2515035, gradient norm = 0.0016794
# [t-SNE] Iteration 175: error = 1.2458454, gradient norm = 0.0016520
# [t-SNE] Iteration 200: error = 1.2442878, gradient norm = 0.0016448
# [t-SNE] Iteration 225: error = 1.2438730, gradient norm = 0.0016425
# [t-SNE] Iteration 250: error = 1.2437005, gradient norm = 0.0016423
# [t-SNE] Iteration 275: error = 1.2436104, gradient norm = 0.0016467
# [t-SNE] Iteration 300: error = 1.2436422, gradient norm = 0.0016423
# [t-SNE] Iteration 325: error = 1.2435771, gradient norm = 0.0016469
# [t-SNE] Iteration 350: error = 1.2435920, gradient norm = 0.0016468
# [t-SNE] Iteration 375: error = 1.2435663, gradient norm = 0.0016471
# [t-SNE] Iteration 400: error = 1.2436271, gradient norm = 0.0016425
# [t-SNE] Iteration 425: error = 1.2435609, gradient norm = 0.0016471
# [t-SNE] Iteration 425: error difference 0.000000. Finished.
# [t-SNE] Error after 425 iterations: 1.334635
#  Time taken: 3 minutes and 47.04 seconds.
#
#  Running Isolation Forest:
# /kaggle/dev/jovan/mercedes-benz-greener-manufacturing/venv-mercedes/lib/python3.5/site-packages/ipykernel_launcher.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#  Found 85 outlier points
#  Time taken: 0 minutes and 7.74 seconds.
#
#  Running Random Forest Regressor (10-fold):
# /kaggle/dev/jovan/mercedes-benz-greener-manufacturing/venv-mercedes/lib/python3.5/site-packages/ipykernel_launcher.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#  Time taken: 0 minutes and 13.8 seconds.
#  Presumed outlier point for train ID = 0 is test ID = 3084 ; their Euclidean distance from t-SNE embedding is 0.00048114
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636804548>
#  Presumed outlier point for train ID = 6 is test ID = 2392 ; their Euclidean distance from t-SNE embedding is 0.55056130
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367eba88>
#  Presumed outlier point for train ID = 7 is test ID = 5199 ; their Euclidean distance from t-SNE embedding is 0.05340328
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c65c8>
#  Presumed outlier point for train ID = 9 is test ID = 4648 ; their Euclidean distance from t-SNE embedding is 0.12928096
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f1c88>
#  Presumed outlier point for train ID = 13 is test ID = 6676 ; their Euclidean distance from t-SNE embedding is 0.00664494
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f1988>
#  Presumed outlier point for train ID = 18 is test ID = 2142 ; their Euclidean distance from t-SNE embedding is 0.05081872
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bfec8>
#  Presumed outlier point for train ID = 24 is test ID = 21 ; their Euclidean distance from t-SNE embedding is 0.00000037
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf948>
#  Presumed outlier point for train ID = 25 is test ID = 3856 ; their Euclidean distance from t-SNE embedding is 0.00049299
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf148>
#  Presumed outlier point for train ID = 27 is test ID = 519 ; their Euclidean distance from t-SNE embedding is 0.01852305
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf9c8>
#  Presumed outlier point for train ID = 30 is test ID = 6995 ; their Euclidean distance from t-SNE embedding is 0.00000053
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf548>
#  Presumed outlier point for train ID = 31 is test ID = 6868 ; their Euclidean distance from t-SNE embedding is 0.00079062
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bfe88>
#  Presumed outlier point for train ID = 32 is test ID = 29 ; their Euclidean distance from t-SNE embedding is 0.00000013
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bff08>
#  Presumed outlier point for train ID = 34 is test ID = 3647 ; their Euclidean distance from t-SNE embedding is 0.00056358
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf508>
#  Presumed outlier point for train ID = 36 is test ID = 41 ; their Euclidean distance from t-SNE embedding is 0.00000093
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf148>
#  Presumed outlier point for train ID = 37 is test ID = 6657 ; their Euclidean distance from t-SNE embedding is 0.00900938
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf9c8>
#  Presumed outlier point for train ID = 38 is test ID = 7383 ; their Euclidean distance from t-SNE embedding is 0.00067383
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf548>
#  Presumed outlier point for train ID = 39 is test ID = 41 ; their Euclidean distance from t-SNE embedding is 0.00000086
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bfe88>
#  Presumed outlier point for train ID = 40 is test ID = 4178 ; their Euclidean distance from t-SNE embedding is 0.03587786
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf548>
#  Presumed outlier point for train ID = 44 is test ID = 1054 ; their Euclidean distance from t-SNE embedding is 0.00000071
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bff08>
#  Presumed outlier point for train ID = 47 is test ID = 409 ; their Euclidean distance from t-SNE embedding is 0.01369183
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf148>
#  Presumed outlier point for train ID = 48 is test ID = 883 ; their Euclidean distance from t-SNE embedding is 0.00001005
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f4a48>
#  Presumed outlier point for train ID = 49 is test ID = 996 ; their Euclidean distance from t-SNE embedding is 0.00000157
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367a2688>
#  Presumed outlier point for train ID = 50 is test ID = 7484 ; their Euclidean distance from t-SNE embedding is 0.00001440
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f4a48>
#  Presumed outlier point for train ID = 52 is test ID = 288 ; their Euclidean distance from t-SNE embedding is 0.00000044
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367eb148>
#  Presumed outlier point for train ID = 54 is test ID = 1943 ; their Euclidean distance from t-SNE embedding is 0.00085966
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636818bc8>
#  Presumed outlier point for train ID = 60 is test ID = 2162 ; their Euclidean distance from t-SNE embedding is 0.00000101
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367eb148>
#  Presumed outlier point for train ID = 61 is test ID = 2321 ; their Euclidean distance from t-SNE embedding is 0.00010028
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bfe88>
#  Presumed outlier point for train ID = 62 is test ID = 99 ; their Euclidean distance from t-SNE embedding is 0.00016757
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bff08>
#  Presumed outlier point for train ID = 66 is test ID = 2269 ; their Euclidean distance from t-SNE embedding is 0.00000251
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf9c8>
#  Presumed outlier point for train ID = 67 is test ID = 288 ; their Euclidean distance from t-SNE embedding is 0.00000044
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf508>
#  Presumed outlier point for train ID = 68 is test ID = 492 ; their Euclidean distance from t-SNE embedding is 0.00000782
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bfe88>
#  Presumed outlier point for train ID = 70 is test ID = 4005 ; their Euclidean distance from t-SNE embedding is 0.11124533
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bff08>
#  Presumed outlier point for train ID = 74 is test ID = 288 ; their Euclidean distance from t-SNE embedding is 0.00000031
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf508>
#  Presumed outlier point for train ID = 75 is test ID = 4043 ; their Euclidean distance from t-SNE embedding is 0.00028014
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf508>
#  Presumed outlier point for train ID = 79 is test ID = 6700 ; their Euclidean distance from t-SNE embedding is 0.00011654
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636805648>
#  Presumed outlier point for train ID = 80 is test ID = 6242 ; their Euclidean distance from t-SNE embedding is 0.00560109
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636805a08>
#  Presumed outlier point for train ID = 81 is test ID = 1826 ; their Euclidean distance from t-SNE embedding is 0.00030910
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56368051c8>
#  Presumed outlier point for train ID = 86 is test ID = 581 ; their Euclidean distance from t-SNE embedding is 0.00001480
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56368051c8>
#  Presumed outlier point for train ID = 90 is test ID = 492 ; their Euclidean distance from t-SNE embedding is 0.00001073
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf548>
#  Presumed outlier point for train ID = 92 is test ID = 6629 ; their Euclidean distance from t-SNE embedding is 0.00174947
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56368051c8>
#  Presumed outlier point for train ID = 100 is test ID = 8314 ; their Euclidean distance from t-SNE embedding is 0.00034963
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bfe88>
#  Presumed outlier point for train ID = 102 is test ID = 5658 ; their Euclidean distance from t-SNE embedding is 0.00027788
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bfe88>
#  Presumed outlier point for train ID = 106 is test ID = 4380 ; their Euclidean distance from t-SNE embedding is 0.00068446
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636805648>
#  Presumed outlier point for train ID = 107 is test ID = 247 ; their Euclidean distance from t-SNE embedding is 0.01023781
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf508>
#  Presumed outlier point for train ID = 108 is test ID = 4842 ; their Euclidean distance from t-SNE embedding is 0.00154876
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3288>
#  Presumed outlier point for train ID = 109 is test ID = 288 ; their Euclidean distance from t-SNE embedding is 0.00000031
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3288>
#  Presumed outlier point for train ID = 112 is test ID = 155 ; their Euclidean distance from t-SNE embedding is 0.00014570
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3408>
#  Presumed outlier point for train ID = 116 is test ID = 4803 ; their Euclidean distance from t-SNE embedding is 0.00078160
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3f08>
#  Presumed outlier point for train ID = 118 is test ID = 7805 ; their Euclidean distance from t-SNE embedding is 0.02496834
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3048>
#  Presumed outlier point for train ID = 119 is test ID = 5356 ; their Euclidean distance from t-SNE embedding is 0.00042012
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c31c8>
#  Presumed outlier point for train ID = 124 is test ID = 111 ; their Euclidean distance from t-SNE embedding is 0.29019907
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3f08>
#  Presumed outlier point for train ID = 125 is test ID = 41 ; their Euclidean distance from t-SNE embedding is 0.00000036
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367d7508>
#  Presumed outlier point for train ID = 127 is test ID = 235 ; their Euclidean distance from t-SNE embedding is 0.00000000
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3588>
#  Presumed outlier point for train ID = 128 is test ID = 5822 ; their Euclidean distance from t-SNE embedding is 0.02869163
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3288>
#  Presumed outlier point for train ID = 129 is test ID = 2447 ; their Euclidean distance from t-SNE embedding is 0.00002291
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3dc8>
#  Presumed outlier point for train ID = 130 is test ID = 2178 ; their Euclidean distance from t-SNE embedding is 0.00009736
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370b7fc8>
#  Presumed outlier point for train ID = 131 is test ID = 940 ; their Euclidean distance from t-SNE embedding is 0.01046026
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3dc8>
#  Presumed outlier point for train ID = 133 is test ID = 1340 ; their Euclidean distance from t-SNE embedding is 0.04029708
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3f08>
#  Presumed outlier point for train ID = 134 is test ID = 231 ; their Euclidean distance from t-SNE embedding is 0.00000000
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3f08>
#  Presumed outlier point for train ID = 136 is test ID = 6116 ; their Euclidean distance from t-SNE embedding is 0.00536762
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3f08>
#  Presumed outlier point for train ID = 139 is test ID = 1244 ; their Euclidean distance from t-SNE embedding is 0.00168586
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370b7388>
#  Presumed outlier point for train ID = 141 is test ID = 4665 ; their Euclidean distance from t-SNE embedding is 0.00009795
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3788>
#  Presumed outlier point for train ID = 143 is test ID = 1978 ; their Euclidean distance from t-SNE embedding is 0.00000611
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3788>
#  Presumed outlier point for train ID = 145 is test ID = 6964 ; their Euclidean distance from t-SNE embedding is 0.01173960
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370b7b88>
#  Presumed outlier point for train ID = 146 is test ID = 367 ; their Euclidean distance from t-SNE embedding is 0.00001042
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3588>
#  Presumed outlier point for train ID = 147 is test ID = 5123 ; their Euclidean distance from t-SNE embedding is 0.00035259
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3b88>
#  Presumed outlier point for train ID = 150 is test ID = 6216 ; their Euclidean distance from t-SNE embedding is 0.00159785
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3dc8>
#  Presumed outlier point for train ID = 151 is test ID = 2455 ; their Euclidean distance from t-SNE embedding is 0.01031280
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ace88>
#  Presumed outlier point for train ID = 152 is test ID = 7358 ; their Euclidean distance from t-SNE embedding is 0.00182402
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3048>
#  Presumed outlier point for train ID = 153 is test ID = 4469 ; their Euclidean distance from t-SNE embedding is 0.00196754
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3dc8>
#  Presumed outlier point for train ID = 154 is test ID = 4994 ; their Euclidean distance from t-SNE embedding is 0.00000114
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3b88>
#  Presumed outlier point for train ID = 158 is test ID = 1076 ; their Euclidean distance from t-SNE embedding is 0.00395246
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3588>
#  Presumed outlier point for train ID = 159 is test ID = 231 ; their Euclidean distance from t-SNE embedding is 0.00000000
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3dc8>
#  Presumed outlier point for train ID = 160 is test ID = 1524 ; their Euclidean distance from t-SNE embedding is 0.00000636
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3f08>
#  Presumed outlier point for train ID = 161 is test ID = 551 ; their Euclidean distance from t-SNE embedding is 0.00016146
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3f08>
#  Presumed outlier point for train ID = 164 is test ID = 660 ; their Euclidean distance from t-SNE embedding is 0.00542587
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367acc08>
#  Presumed outlier point for train ID = 165 is test ID = 2798 ; their Euclidean distance from t-SNE embedding is 0.00842044
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3f08>
#  Presumed outlier point for train ID = 166 is test ID = 558 ; their Euclidean distance from t-SNE embedding is 0.00000990
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367acc08>
#  Presumed outlier point for train ID = 168 is test ID = 3979 ; their Euclidean distance from t-SNE embedding is 0.00065556
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3788>
#  Presumed outlier point for train ID = 169 is test ID = 41 ; their Euclidean distance from t-SNE embedding is 0.00000010
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3dc8>
#  Presumed outlier point for train ID = 170 is test ID = 350 ; their Euclidean distance from t-SNE embedding is 0.00254649
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3588>
#  Presumed outlier point for train ID = 171 is test ID = 5099 ; their Euclidean distance from t-SNE embedding is 0.00013814
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3588>
#  Presumed outlier point for train ID = 173 is test ID = 1260 ; their Euclidean distance from t-SNE embedding is 0.00023865
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ace88>
#  Presumed outlier point for train ID = 174 is test ID = 101 ; their Euclidean distance from t-SNE embedding is 0.00000014
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ace88>
#  Presumed outlier point for train ID = 175 is test ID = 501 ; their Euclidean distance from t-SNE embedding is 0.00000404
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3f08>
#  Presumed outlier point for train ID = 176 is test ID = 581 ; their Euclidean distance from t-SNE embedding is 0.00001119
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3788>
#  Presumed outlier point for train ID = 177 is test ID = 5554 ; their Euclidean distance from t-SNE embedding is 0.00007067
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3b88>
#  Presumed outlier point for train ID = 178 is test ID = 1915 ; their Euclidean distance from t-SNE embedding is 0.00742368
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c3dc8>
#  Presumed outlier point for train ID = 184 is test ID = 3468 ; their Euclidean distance from t-SNE embedding is 0.00076665
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367acc08>
#  Presumed outlier point for train ID = 186 is test ID = 1954 ; their Euclidean distance from t-SNE embedding is 0.00000005
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370c7988>
#  Presumed outlier point for train ID = 190 is test ID = 288 ; their Euclidean distance from t-SNE embedding is 0.00000020
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367acc08>
#  Presumed outlier point for train ID = 197 is test ID = 5595 ; their Euclidean distance from t-SNE embedding is 0.02142416
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ace88>
#  Presumed outlier point for train ID = 200 is test ID = 7242 ; their Euclidean distance from t-SNE embedding is 0.00000012
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ace88>
#  Presumed outlier point for train ID = 202 is test ID = 1054 ; their Euclidean distance from t-SNE embedding is 0.00000040
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367acc08>
#  Presumed outlier point for train ID = 203 is test ID = 4739 ; their Euclidean distance from t-SNE embedding is 0.00000534
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367b9288>
#  Presumed outlier point for train ID = 207 is test ID = 117 ; their Euclidean distance from t-SNE embedding is 0.00000009
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367aca48>
#  Presumed outlier point for train ID = 208 is test ID = 7462 ; their Euclidean distance from t-SNE embedding is 0.00007921
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ace88>
#  Presumed outlier point for train ID = 209 is test ID = 226 ; their Euclidean distance from t-SNE embedding is 0.00000000
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367acc08>
#  Presumed outlier point for train ID = 212 is test ID = 117 ; their Euclidean distance from t-SNE embedding is 0.00000009
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ace88>
#  Presumed outlier point for train ID = 213 is test ID = 4820 ; their Euclidean distance from t-SNE embedding is 0.00000025
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367b98c8>
#  Presumed outlier point for train ID = 214 is test ID = 2129 ; their Euclidean distance from t-SNE embedding is 0.00007707
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367eb508>
#  Presumed outlier point for train ID = 215 is test ID = 5583 ; their Euclidean distance from t-SNE embedding is 0.02340476
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370d0dc8>
#  Presumed outlier point for train ID = 217 is test ID = 283 ; their Euclidean distance from t-SNE embedding is 0.00000600
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370d03c8>
#  Presumed outlier point for train ID = 218 is test ID = 6595 ; their Euclidean distance from t-SNE embedding is 0.00096729
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370d0608>
#  Presumed outlier point for train ID = 222 is test ID = 51 ; their Euclidean distance from t-SNE embedding is 0.00000061
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367b9348>
#  Presumed outlier point for train ID = 223 is test ID = 7615 ; their Euclidean distance from t-SNE embedding is 0.00012930
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367b9548>
#  Presumed outlier point for train ID = 224 is test ID = 117 ; their Euclidean distance from t-SNE embedding is 0.00000009
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367b9548>
#  Presumed outlier point for train ID = 225 is test ID = 4693 ; their Euclidean distance from t-SNE embedding is 0.00065513
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367b98c8>
#  Presumed outlier point for train ID = 229 is test ID = 1029 ; their Euclidean distance from t-SNE embedding is 0.00068577
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367b98c8>
#  Presumed outlier point for train ID = 232 is test ID = 830 ; their Euclidean distance from t-SNE embedding is 0.02176643
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367b98c8>
#  Presumed outlier point for train ID = 233 is test ID = 231 ; their Euclidean distance from t-SNE embedding is 0.00000000
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367b9348>
#  Presumed outlier point for train ID = 234 is test ID = 1020 ; their Euclidean distance from t-SNE embedding is 0.00537007
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7108>
#  Presumed outlier point for train ID = 237 is test ID = 552 ; their Euclidean distance from t-SNE embedding is 0.00113764
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7088>
#  Presumed outlier point for train ID = 239 is test ID = 5509 ; their Euclidean distance from t-SNE embedding is 0.00001228
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f78c8>
#  Presumed outlier point for train ID = 240 is test ID = 3695 ; their Euclidean distance from t-SNE embedding is 0.00129721
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7f88>
#  Presumed outlier point for train ID = 241 is test ID = 1027 ; their Euclidean distance from t-SNE embedding is 0.00001609
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7208>
#  Presumed outlier point for train ID = 246 is test ID = 648 ; their Euclidean distance from t-SNE embedding is 0.00000122
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f70c8>
#  Presumed outlier point for train ID = 252 is test ID = 5567 ; their Euclidean distance from t-SNE embedding is 0.00071497
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7388>
#  Presumed outlier point for train ID = 255 is test ID = 960 ; their Euclidean distance from t-SNE embedding is 0.00330778
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7f88>
#  Presumed outlier point for train ID = 260 is test ID = 4005 ; their Euclidean distance from t-SNE embedding is 0.01797575
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7988>
#  Presumed outlier point for train ID = 261 is test ID = 2614 ; their Euclidean distance from t-SNE embedding is 0.00162974
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7bc8>
#  Presumed outlier point for train ID = 263 is test ID = 76 ; their Euclidean distance from t-SNE embedding is 0.00007432
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7208>
#  Presumed outlier point for train ID = 264 is test ID = 543 ; their Euclidean distance from t-SNE embedding is 0.00000203
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7288>
#  Presumed outlier point for train ID = 265 is test ID = 273 ; their Euclidean distance from t-SNE embedding is 0.00000098
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f70c8>
#  Presumed outlier point for train ID = 268 is test ID = 257 ; their Euclidean distance from t-SNE embedding is 0.00010553
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7f88>
#  Presumed outlier point for train ID = 269 is test ID = 4869 ; their Euclidean distance from t-SNE embedding is 0.00002164
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f70c8>
#  Presumed outlier point for train ID = 270 is test ID = 1044 ; their Euclidean distance from t-SNE embedding is 0.00045187
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7988>
#  Presumed outlier point for train ID = 271 is test ID = 3550 ; their Euclidean distance from t-SNE embedding is 0.05722727
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f70c8>
#  Presumed outlier point for train ID = 274 is test ID = 2685 ; their Euclidean distance from t-SNE embedding is 0.04167950
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367f7508>
#  Presumed outlier point for train ID = 277 is test ID = 6868 ; their Euclidean distance from t-SNE embedding is 0.24103443
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc608>
#  Presumed outlier point for train ID = 278 is test ID = 41 ; their Euclidean distance from t-SNE embedding is 0.00000007
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cca08>
#  Presumed outlier point for train ID = 281 is test ID = 1969 ; their Euclidean distance from t-SNE embedding is 0.00000001
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc688>
#  Presumed outlier point for train ID = 282 is test ID = 6505 ; their Euclidean distance from t-SNE embedding is 0.00001086
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ccd48>
#  Presumed outlier point for train ID = 284 is test ID = 1172 ; their Euclidean distance from t-SNE embedding is 0.00380427
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc6c8>
#  Presumed outlier point for train ID = 286 is test ID = 6293 ; their Euclidean distance from t-SNE embedding is 0.00381700
#  Ten closest test points (ID, distance):
# <zip object at 0x7f563c696f08>
#  Presumed outlier point for train ID = 287 is test ID = 242 ; their Euclidean distance from t-SNE embedding is 0.00005761
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5646f37cc8>
#  Presumed outlier point for train ID = 294 is test ID = 551 ; their Euclidean distance from t-SNE embedding is 0.00020744
#  Ten closest test points (ID, distance):
# <zip object at 0x7f568456c5c8>
#  Presumed outlier point for train ID = 295 is test ID = 7930 ; their Euclidean distance from t-SNE embedding is 0.00324127
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc488>
#  Presumed outlier point for train ID = 300 is test ID = 2675 ; their Euclidean distance from t-SNE embedding is 0.00000087
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc488>
#  Presumed outlier point for train ID = 301 is test ID = 3094 ; their Euclidean distance from t-SNE embedding is 0.00000005
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ccd08>
#  Presumed outlier point for train ID = 302 is test ID = 610 ; their Euclidean distance from t-SNE embedding is 0.00001582
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc248>
#  Presumed outlier point for train ID = 303 is test ID = 378 ; their Euclidean distance from t-SNE embedding is 0.00000047
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc188>
#  Presumed outlier point for train ID = 308 is test ID = 6752 ; their Euclidean distance from t-SNE embedding is 0.01873775
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ccd08>
#  Presumed outlier point for train ID = 309 is test ID = 4283 ; their Euclidean distance from t-SNE embedding is 0.27278057
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc488>
#  Presumed outlier point for train ID = 310 is test ID = 6116 ; their Euclidean distance from t-SNE embedding is 0.00034846
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc188>
#  Presumed outlier point for train ID = 312 is test ID = 299 ; their Euclidean distance from t-SNE embedding is 0.00000123
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc488>
#  Presumed outlier point for train ID = 315 is test ID = 307 ; their Euclidean distance from t-SNE embedding is 0.00000000
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ccd08>
#  Presumed outlier point for train ID = 317 is test ID = 2460 ; their Euclidean distance from t-SNE embedding is 0.00000538
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367cc0c8>
#  Presumed outlier point for train ID = 318 is test ID = 512 ; their Euclidean distance from t-SNE embedding is 0.00000533
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56368087c8>
#  Presumed outlier point for train ID = 319 is test ID = 6829 ; their Euclidean distance from t-SNE embedding is 0.34459886
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808148>
#  Presumed outlier point for train ID = 320 is test ID = 677 ; their Euclidean distance from t-SNE embedding is 0.00000730
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808c08>
#  Presumed outlier point for train ID = 321 is test ID = 1134 ; their Euclidean distance from t-SNE embedding is 0.08962715
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808508>
#  Presumed outlier point for train ID = 322 is test ID = 4566 ; their Euclidean distance from t-SNE embedding is 0.00134652
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808e08>
#  Presumed outlier point for train ID = 323 is test ID = 7501 ; their Euclidean distance from t-SNE embedding is 0.00004048
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808508>
#  Presumed outlier point for train ID = 325 is test ID = 446 ; their Euclidean distance from t-SNE embedding is 0.00000131
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808308>
#  Presumed outlier point for train ID = 326 is test ID = 1578 ; their Euclidean distance from t-SNE embedding is 0.00026101
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808e08>
#  Presumed outlier point for train ID = 328 is test ID = 2497 ; their Euclidean distance from t-SNE embedding is 0.00000924
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808148>
#  Presumed outlier point for train ID = 331 is test ID = 7603 ; their Euclidean distance from t-SNE embedding is 0.11720271
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808508>
#  Presumed outlier point for train ID = 332 is test ID = 307 ; their Euclidean distance from t-SNE embedding is 0.00001443
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808e08>
#  Presumed outlier point for train ID = 333 is test ID = 7414 ; their Euclidean distance from t-SNE embedding is 0.00598713
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808148>
#  Presumed outlier point for train ID = 334 is test ID = 3776 ; their Euclidean distance from t-SNE embedding is 0.00002774
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808e08>
#  Presumed outlier point for train ID = 335 is test ID = 6593 ; their Euclidean distance from t-SNE embedding is 0.00581637
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808508>
#  Presumed outlier point for train ID = 336 is test ID = 643 ; their Euclidean distance from t-SNE embedding is 0.00201488
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808788>
#  Presumed outlier point for train ID = 341 is test ID = 5846 ; their Euclidean distance from t-SNE embedding is 0.00871917
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636808508>
#  Presumed outlier point for train ID = 342 is test ID = 6105 ; their Euclidean distance from t-SNE embedding is 0.00015768
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807b88>
#  Presumed outlier point for train ID = 344 is test ID = 630 ; their Euclidean distance from t-SNE embedding is 0.00000026
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807ac8>
#  Presumed outlier point for train ID = 348 is test ID = 58 ; their Euclidean distance from t-SNE embedding is 0.00000007
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807c88>
#  Presumed outlier point for train ID = 351 is test ID = 984 ; their Euclidean distance from t-SNE embedding is 0.00001196
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807c88>
#  Presumed outlier point for train ID = 355 is test ID = 5309 ; their Euclidean distance from t-SNE embedding is 0.00000302
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807248>
#  Presumed outlier point for train ID = 356 is test ID = 5 ; their Euclidean distance from t-SNE embedding is 0.00060263
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807888>
#  Presumed outlier point for train ID = 359 is test ID = 6851 ; their Euclidean distance from t-SNE embedding is 0.00007949
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807c08>
#  Presumed outlier point for train ID = 360 is test ID = 2480 ; their Euclidean distance from t-SNE embedding is 0.00016990
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807888>
#  Presumed outlier point for train ID = 361 is test ID = 1514 ; their Euclidean distance from t-SNE embedding is 0.00176669
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807ec8>
#  Presumed outlier point for train ID = 363 is test ID = 4545 ; their Euclidean distance from t-SNE embedding is 0.00000515
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807a08>
#  Presumed outlier point for train ID = 369 is test ID = 5846 ; their Euclidean distance from t-SNE embedding is 0.00790801
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807ec8>
#  Presumed outlier point for train ID = 371 is test ID = 4436 ; their Euclidean distance from t-SNE embedding is 0.01108576
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807248>
#  Presumed outlier point for train ID = 372 is test ID = 5257 ; their Euclidean distance from t-SNE embedding is 0.02129039
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636807208>
#  Presumed outlier point for train ID = 374 is test ID = 3586 ; their Euclidean distance from t-SNE embedding is 0.00147403
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56368078c8>
#  Presumed outlier point for train ID = 375 is test ID = 3645 ; their Euclidean distance from t-SNE embedding is 0.00011097
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636806508>
#  Presumed outlier point for train ID = 376 is test ID = 2407 ; their Euclidean distance from t-SNE embedding is 0.00291939
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636806fc8>
#  Presumed outlier point for train ID = 379 is test ID = 434 ; their Euclidean distance from t-SNE embedding is 0.00000329
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636806f48>
#  Presumed outlier point for train ID = 380 is test ID = 5748 ; their Euclidean distance from t-SNE embedding is 0.00425567
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636806188>
#  Presumed outlier point for train ID = 381 is test ID = 817 ; their Euclidean distance from t-SNE embedding is 0.00012662
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636806fc8>
#  Presumed outlier point for train ID = 383 is test ID = 996 ; their Euclidean distance from t-SNE embedding is 0.00000702
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636806f08>
#  Presumed outlier point for train ID = 385 is test ID = 1267 ; their Euclidean distance from t-SNE embedding is 0.00000215
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636806988>
#  Presumed outlier point for train ID = 386 is test ID = 2587 ; their Euclidean distance from t-SNE embedding is 0.00053678
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636806e48>
#  Presumed outlier point for train ID = 387 is test ID = 96 ; their Euclidean distance from t-SNE embedding is 0.00007536
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636806f08>
#  Presumed outlier point for train ID = 388 is test ID = 480 ; their Euclidean distance from t-SNE embedding is 0.00000000
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636806e48>
#  Presumed outlier point for train ID = 389 is test ID = 3770 ; their Euclidean distance from t-SNE embedding is 0.00937270
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae7c8>
#  Presumed outlier point for train ID = 391 is test ID = 6402 ; their Euclidean distance from t-SNE embedding is 0.00111080
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367b9e48>
#  Presumed outlier point for train ID = 394 is test ID = 1590 ; their Euclidean distance from t-SNE embedding is 0.57158130
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae308>
#  Presumed outlier point for train ID = 397 is test ID = 939 ; their Euclidean distance from t-SNE embedding is 0.00000238
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae688>
#  Presumed outlier point for train ID = 398 is test ID = 5846 ; their Euclidean distance from t-SNE embedding is 0.01014796
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367aedc8>
#  Presumed outlier point for train ID = 400 is test ID = 2556 ; their Euclidean distance from t-SNE embedding is 0.00081503
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae348>
#  Presumed outlier point for train ID = 401 is test ID = 3640 ; their Euclidean distance from t-SNE embedding is 0.02775543
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae348>
#  Presumed outlier point for train ID = 402 is test ID = 5822 ; their Euclidean distance from t-SNE embedding is 0.00068185
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae7c8>
#  Presumed outlier point for train ID = 403 is test ID = 984 ; their Euclidean distance from t-SNE embedding is 0.00001006
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae4c8>
#  Presumed outlier point for train ID = 404 is test ID = 7148 ; their Euclidean distance from t-SNE embedding is 0.00199717
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae348>
#  Presumed outlier point for train ID = 405 is test ID = 518 ; their Euclidean distance from t-SNE embedding is 0.00000000
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae588>
#  Presumed outlier point for train ID = 407 is test ID = 1720 ; their Euclidean distance from t-SNE embedding is 0.00070373
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae108>
#  Presumed outlier point for train ID = 411 is test ID = 2401 ; their Euclidean distance from t-SNE embedding is 0.00006571
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae7c8>
#  Presumed outlier point for train ID = 414 is test ID = 1138 ; their Euclidean distance from t-SNE embedding is 0.00198308
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367aedc8>
#  Presumed outlier point for train ID = 415 is test ID = 72 ; their Euclidean distance from t-SNE embedding is 0.00454052
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae7c8>
#  Presumed outlier point for train ID = 416 is test ID = 498 ; their Euclidean distance from t-SNE embedding is 0.00022973
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae108>
#  Presumed outlier point for train ID = 417 is test ID = 480 ; their Euclidean distance from t-SNE embedding is 0.00000000
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367aef48>
#  Presumed outlier point for train ID = 418 is test ID = 4485 ; their Euclidean distance from t-SNE embedding is 0.00269699
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367ae108>
#  Presumed outlier point for train ID = 422 is test ID = 3371 ; their Euclidean distance from t-SNE embedding is 0.00531371
# ...
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367c2888>
#  Presumed outlier point for train ID = 8324 is test ID = 7945 ; their Euclidean distance from t-SNE embedding is 0.00047818
#  Ten closest test points (ID, distance):
# <zip object at 0x7f563672c2c8>
#  Presumed outlier point for train ID = 8327 is test ID = 6402 ; their Euclidean distance from t-SNE embedding is 0.01394249
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740588>
#  Presumed outlier point for train ID = 8329 is test ID = 6320 ; their Euclidean distance from t-SNE embedding is 0.00000239
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740888>
#  Presumed outlier point for train ID = 8333 is test ID = 8091 ; their Euclidean distance from t-SNE embedding is 0.00000314
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740488>
#  Presumed outlier point for train ID = 8335 is test ID = 1616 ; their Euclidean distance from t-SNE embedding is 0.03075769
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740888>
#  Presumed outlier point for train ID = 8336 is test ID = 5653 ; their Euclidean distance from t-SNE embedding is 0.01751278
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740888>
#  Presumed outlier point for train ID = 8337 is test ID = 5550 ; their Euclidean distance from t-SNE embedding is 0.00001644
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740588>
#  Presumed outlier point for train ID = 8340 is test ID = 2054 ; their Euclidean distance from t-SNE embedding is 0.00014764
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740588>
#  Presumed outlier point for train ID = 8342 is test ID = 4666 ; their Euclidean distance from t-SNE embedding is 0.01269912
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367bab48>
#  Presumed outlier point for train ID = 8343 is test ID = 3395 ; their Euclidean distance from t-SNE embedding is 0.00005310
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740588>
#  Presumed outlier point for train ID = 8344 is test ID = 8094 ; their Euclidean distance from t-SNE embedding is 0.00000017
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367419c8>
#  Presumed outlier point for train ID = 8348 is test ID = 8208 ; their Euclidean distance from t-SNE embedding is 0.00000000
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636773488>
#  Presumed outlier point for train ID = 8350 is test ID = 7554 ; their Euclidean distance from t-SNE embedding is 0.00078181
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740fc8>
#  Presumed outlier point for train ID = 8354 is test ID = 3867 ; their Euclidean distance from t-SNE embedding is 0.00003217
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740fc8>
#  Presumed outlier point for train ID = 8356 is test ID = 7437 ; their Euclidean distance from t-SNE embedding is 0.00171358
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740fc8>
#  Presumed outlier point for train ID = 8357 is test ID = 8413 ; their Euclidean distance from t-SNE embedding is 0.00043763
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740588>
#  Presumed outlier point for train ID = 8362 is test ID = 8233 ; their Euclidean distance from t-SNE embedding is 0.00000184
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367c25c8>
#  Presumed outlier point for train ID = 8367 is test ID = 7323 ; their Euclidean distance from t-SNE embedding is 0.00000333
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367c25c8>
#  Presumed outlier point for train ID = 8368 is test ID = 1979 ; their Euclidean distance from t-SNE embedding is 0.00083022
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367c25c8>
#  Presumed outlier point for train ID = 8369 is test ID = 8214 ; their Euclidean distance from t-SNE embedding is 0.00000224
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636773408>
#  Presumed outlier point for train ID = 8371 is test ID = 6159 ; their Euclidean distance from t-SNE embedding is 0.01275122
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367bab48>
#  Presumed outlier point for train ID = 8373 is test ID = 4141 ; their Euclidean distance from t-SNE embedding is 0.00606831
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367c2888>
#  Presumed outlier point for train ID = 8374 is test ID = 6388 ; their Euclidean distance from t-SNE embedding is 0.00291407
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740888>
#  Presumed outlier point for train ID = 8375 is test ID = 2955 ; their Euclidean distance from t-SNE embedding is 0.00042198
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56370bf788>
#  Presumed outlier point for train ID = 8378 is test ID = 1459 ; their Euclidean distance from t-SNE embedding is 0.00003717
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367416c8>
#  Presumed outlier point for train ID = 8382 is test ID = 8233 ; their Euclidean distance from t-SNE embedding is 0.00000037
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636741e48>
#  Presumed outlier point for train ID = 8383 is test ID = 4675 ; their Euclidean distance from t-SNE embedding is 0.00106684
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740488>
#  Presumed outlier point for train ID = 8384 is test ID = 2054 ; their Euclidean distance from t-SNE embedding is 0.00011131
#  Ten closest test points (ID, distance):
# <zip object at 0x7f563672c2c8>
#  Presumed outlier point for train ID = 8385 is test ID = 3227 ; their Euclidean distance from t-SNE embedding is 0.00021818
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367aed08>
#  Presumed outlier point for train ID = 8387 is test ID = 1093 ; their Euclidean distance from t-SNE embedding is 0.00001218
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367c25c8>
#  Presumed outlier point for train ID = 8390 is test ID = 6292 ; their Euclidean distance from t-SNE embedding is 0.00822022
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636773408>
#  Presumed outlier point for train ID = 8392 is test ID = 8233 ; their Euclidean distance from t-SNE embedding is 0.00000011
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367c25c8>
#  Presumed outlier point for train ID = 8393 is test ID = 3781 ; their Euclidean distance from t-SNE embedding is 0.11102865
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367c2888>
#  Presumed outlier point for train ID = 8395 is test ID = 6344 ; their Euclidean distance from t-SNE embedding is 0.00000375
#  Ten closest test points (ID, distance):
# <zip object at 0x7f56367bab48>
#  Presumed outlier point for train ID = 8397 is test ID = 1923 ; their Euclidean distance from t-SNE embedding is 0.73691312
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636741748>
#  Presumed outlier point for train ID = 8399 is test ID = 7616 ; their Euclidean distance from t-SNE embedding is 0.00000016
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636741e88>
#  Presumed outlier point for train ID = 8402 is test ID = 6947 ; their Euclidean distance from t-SNE embedding is 0.00000402
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636741a48>
#  Presumed outlier point for train ID = 8403 is test ID = 6547 ; their Euclidean distance from t-SNE embedding is 0.00001819
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636741c08>
#  Presumed outlier point for train ID = 8405 is test ID = 6445 ; their Euclidean distance from t-SNE embedding is 0.00203628
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740988>
#  Presumed outlier point for train ID = 8406 is test ID = 8409 ; their Euclidean distance from t-SNE embedding is 0.00000490
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740488>
#  Presumed outlier point for train ID = 8412 is test ID = 5707 ; their Euclidean distance from t-SNE embedding is 0.00005094
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740988>
#  Presumed outlier point for train ID = 8415 is test ID = 8341 ; their Euclidean distance from t-SNE embedding is 0.00000013
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636740488>
#  Presumed outlier point for train ID = 8417 is test ID = 2366 ; their Euclidean distance from t-SNE embedding is 0.00007884
#  Ten closest test points (ID, distance):
# <zip object at 0x7f5636741048>
# /kaggle/dev/jovan/mercedes-benz-greener-manufacturing/venv-mercedes/lib/python3.5/site-packages/ipykernel_launcher.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /kaggle/dev/jovan/mercedes-benz-greener-manufacturing/venv-mercedes/lib/python3.5/site-packages/ipykernel_launcher.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#  Time taken: 0 minutes and 9.74 seconds.
# ------ RUNNING for treshold: 0.5
#
# # Reading and Processing Data
#
#  Initial Train Set Matrix Dimensions: 4209 x 376
#
#  Initial Test Set Matrix Dimensions: 4209 x 376
#
#  Converting categorical features:
#  Converting X0
#  Converting X1
#  Converting X2
#  Converting X3
#  Converting X4
#  Converting X5
#  Converting X6
#  Converting X8
#
#  Number of columns before cleaning: 579
#  Column X16 is identical to X2_ap. Removing X2_ap
#  Column X17 is identical to X382. Removing X382
#  Column X23 is identical to X2_f. Removing X2_f
#  Column X26 is identical to X2_b. Removing X2_b
#  Column X28 is identical to X2_n. Removing X2_n
#  Column X30 is identical to X2_ag. Removing X2_ag
#  Column X31 is identical to X35. Removing X35
#  Column X31 is identical to X37. Removing X37
#  Column X32 is identical to X2_a. Removing X2_a
#  Column X33 is identical to X39. Removing X39
#  Column X35 is identical to X37. Removing X37
#  Column X36 is identical to X2_z. Removing X2_z
#  Column X44 is identical to X302. Removing X302
#  Column X48 is identical to X113. Removing X113
#  Column X48 is identical to X134. Removing X134
#  Column X48 is identical to X147. Removing X147
#  Column X48 is identical to X222. Removing X222
#  Column X48 is identical to X2_s. Removing X2_s
#  Column X53 is identical to X102. Removing X102
#  Column X53 is identical to X214. Removing X214
#  Column X53 is identical to X239. Removing X239
#  Column X53 is identical to X2_t. Removing X2_t
#  Column X54 is identical to X76. Removing X76
#  Column X58 is identical to X324. Removing X324
#  Column X59 is identical to X2_au. Removing X2_au
#  Column X60 is identical to X253. Removing X253
#  Column X60 is identical to X385. Removing X385
#  Column X62 is identical to X172. Removing X172
#  Column X62 is identical to X216. Removing X216
#  Column X62 is identical to X2_k. Removing X2_k
#  Column X67 is identical to X213. Removing X213
#  Column X67 is identical to X2_aw. Removing X2_aw
#  Column X71 is identical to X84. Removing X84
#  Column X71 is identical to X244. Removing X244
#  Column X83 is identical to X2_q. Removing X2_q
#  Column X84 is identical to X244. Removing X244
#  Column X86 is identical to X2_h. Removing X2_h
#  Column X92 is identical to X2_p. Removing X2_p
#  Column X97 is identical to X2_d. Removing X2_d
#  Column X102 is identical to X214. Removing X214
#  Column X102 is identical to X239. Removing X239
#  Column X102 is identical to X2_t. Removing X2_t
#  Column X107 is identical to X2_ad. Removing X2_ad
#  Column X112 is identical to X199. Removing X199
#  Column X112 is identical to X2_g. Removing X2_g
#  Column X113 is identical to X134. Removing X134
#  Column X113 is identical to X147. Removing X147
#  Column X113 is identical to X222. Removing X222
#  Column X113 is identical to X2_s. Removing X2_s
#  Column X118 is identical to X119. Removing X119
#  Column X125 is identical to X227. Removing X227
#  Column X125 is identical to X2_ac. Removing X2_ac
#  Column X134 is identical to X147. Removing X147
#  Column X134 is identical to X222. Removing X222
#  Column X134 is identical to X2_s. Removing X2_s
#  Column X138 is identical to X146. Removing X146
#  Column X147 is identical to X222. Removing X222
#  Column X147 is identical to X2_s. Removing X2_s
#  Column X152 is identical to X226. Removing X226
#  Column X152 is identical to X326. Removing X326
#  Column X155 is identical to X360. Removing X360
#  Column X172 is identical to X216. Removing X216
#  Column X172 is identical to X2_k. Removing X2_k
#  Column X184 is identical to X262. Removing X262
#  Column X184 is identical to X2_at. Removing X2_at
#  Column X199 is identical to X2_g. Removing X2_g
#  Column X211 is identical to X2_aq. Removing X2_aq
#  Column X213 is identical to X2_aw. Removing X2_aw
#  Column X214 is identical to X239. Removing X239
#  Column X214 is identical to X2_t. Removing X2_t
#  Column X215 is identical to X2_ai. Removing X2_ai
#  Column X216 is identical to X2_k. Removing X2_k
#  Column X222 is identical to X2_s. Removing X2_s
#  Column X226 is identical to X326. Removing X326
#  Column X227 is identical to X2_ac. Removing X2_ac
#  Column X230 is identical to X254. Removing X254
#  Column X232 is identical to X279. Removing X279
#  Column X239 is identical to X2_t. Removing X2_t
#  Column X240 is identical to X364. Removing X364
#  Column X251 is identical to X2_as. Removing X2_as
#  Column X253 is identical to X385. Removing X385
#  Column X257 is identical to X2_o. Removing X2_o
#  Column X260 is identical to X2_am. Removing X2_am
#  Column X262 is identical to X2_at. Removing X2_at
#  Column X277 is identical to X0_bc. Removing X0_bc
#  Column X290 is identical to X293. Removing X293
#  Column X290 is identical to X330. Removing X330
#  Column X293 is identical to X330. Removing X330
#  Column X295 is identical to X296. Removing X296
#  Column X298 is identical to X299. Removing X299
#
#  Number of columns after cleaning: 517
#
#  Final Matrix Dimensions: 8418 x 517
#  Time taken: 0 minutes and 3.83 seconds.
#
#  Calculating t-SNE embedding:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 8418
# [t-SNE] Computed conditional probabilities for sample 2000 / 8418
# [t-SNE] Computed conditional probabilities for sample 3000 / 8418
# [t-SNE] Computed conditional probabilities for sample 4000 / 8418
# [t-SNE] Computed conditional probabilities for sample 5000 / 8418
# [t-SNE] Computed conditional probabilities for sample 6000 / 8418
# [t-SNE] Computed conditional probabilities for sample 7000 / 8418
# [t-SNE] Computed conditional probabilities for sample 8000 / 8418
# [t-SNE] Computed conditional probabilities for sample 8418 / 8418
# [t-SNE] Mean sigma: 1.247069
# [t-SNE] Iteration 25: error = 1.4710975, gradient norm = 0.0039841
# [t-SNE] Iteration 50: error = 1.4560602, gradient norm = 0.0036393
# [t-SNE] Iteration 75: error = 1.3648686, gradient norm = 0.0024294
# [t-SNE] Iteration 100: error = 1.3346347, gradient norm = 0.0021887
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 1.334635
# [t-SNE] Iteration 125: error = 1.2733716, gradient norm = 0.0017893
# [t-SNE] Iteration 150: error = 1.2515035, gradient norm = 0.0016794
# [t-SNE] Iteration 175: error = 1.2458454, gradient norm = 0.0016520
# [t-SNE] Iteration 200: error = 1.2442878, gradient norm = 0.0016448
# [t-SNE] Iteration 225: error = 1.2438730, gradient norm = 0.0016425
# [t-SNE] Iteration 250: error = 1.2437005, gradient norm = 0.0016423
# [t-SNE] Iteration 275: error = 1.2436104, gradient norm = 0.0016467
# [t-SNE] Iteration 300: error = 1.2436422, gradient norm = 0.0016423
# [t-SNE] Iteration 325: error = 1.2435771, gradient norm = 0.0016469
# [t-SNE] Iteration 350: error = 1.2435920, gradient norm = 0.0016468
# [t-SNE] Iteration 375: error = 1.2435663, gradient norm = 0.0016471
# [t-SNE] Iteration 400: error = 1.2436271, gradient norm = 0.0016425

# %%
train = pd.read_csv(os.path.join(DATA_PATH, 'train.csv'))
test = pd.read_csv(os.path.join(DATA_PATH, 'test.csv'))
train = train.iloc[:,0:1]
test = test.iloc[:,0:1]


def outlier_constructor(outlier_name, outlier_file_train, outlier_file_test):
    global train
    outliers_train = pd.read_csv(os.path.join(ASSET_PATH, outlier_file_train))
    outliers_train[outlier_name] = 1.0
    outliers_train = outliers_train[['ID', outlier_name]]
    train = pd.merge(train, outliers_train, on='ID', how='left')
    train[outlier_name] = train[outlier_name].apply(lambda x: 1 if x==1.0 else 0)
    
    global test
    outliers_test = pd.read_csv(os.path.join(ASSET_PATH, outlier_file_test))    
    outliers_test = outliers_test.drop_duplicates()
    outliers_test[outlier_name] = 1.0
    outliers_test = outliers_test[['ID', outlier_name]]
    test = pd.merge(test, outliers_test, on='ID', how='left')
    test[outlier_name] = test[outlier_name].apply(lambda x: 1 if x==1.0 else 0)
    
    
    return

for i, threshold in enumerate(threshold_list):
    outlier_name = 'is_outlier_' + threshold[1]
    outlier_file_train = 'train-outliers_' + threshold[1] + '.csv'
    outlier_file_test = 'test-outliers_' + threshold[1] + '.csv'
    outlier_constructor(outlier_name, outlier_file_train, outlier_file_test)

# %%
train.to_csv(os.path.join(ASSET_PATH, 'train_outlier_list.csv'), index=False)
test.to_csv(os.path.join(ASSET_PATH, 'test_outlier_list.csv'), index=False)
